# %% [markdown]
# # DSRT WAE — Complete Feature Registry
# ## Every Feature. Every Module. Every Phase.
#
# ---
#
# ## Full Feature Table
#
# | # | Module | Phase | Version | Category | Feature Name | What It Does | Data Source | Tech Stack | Priority | Status |
# |---|--------|-------|---------|----------|--------------|--------------|-------------|------------|----------|--------|
# | 001 | Core Engine | 1 | V1 | Infrastructure | Master Cycle Orchestrator | Runs the full intelligence pipeline every 30 minutes. Coordinates all source modules, processors, and outputs in sequence. Single `runCycle()` function controls everything. | Internal | Node.js | P0 | ✅ LIVE |
# | 002 | GDELT Source | 1 | V1 | Data Ingestion | GDELT Event Puller | Queries the Global Database of Events across 8 strategic themes (conflict, geopolitics, economy, military, energy, political, tech, climate). Free, unlimited, updated every 15 min. | GDELT Project API | Node.js fetch | P0 | ✅ LIVE |
# | 003 | RSS Source | 1 | V1 | Data Ingestion | Global RSS Aggregator | Pulls live news from 18 major international outlets simultaneously (BBC, NYT, Al Jazeera, France24, Guardian, Bloomberg, Defense News, DW, SCMP, etc). Parallel fetch. | 18 RSS Feeds | rss-parser | P0 | ✅ LIVE |
# | 004 | Deduplicator | 1 | V1 | Processing | Event Deduplication Engine | Collapses same news story appearing across 17 sources into 1 event. Uses MD5 hashing on normalized titles + Jaccard similarity (55% word overlap threshold). Keeps richest version. | Internal | Node.js crypto | P0 | ✅ LIVE |
# | 005 | Classifier | 1 | V1 | Processing | AI Event Classifier | Categorizes every event into 11 categories (hot_conflict, military, geopolitics, economy, energy, technology, climate, social, health, diplomacy, general) using keyword matching. Extracts 50+ countries. | Internal | Rule-based NLP | P0 | ✅ LIVE |
# | 006 | Heat Scorer | 1 | V1 | Processing | Global Heat Scoring Engine | Assigns 0–10 impact score to every event based on category base score, high-impact word detection, nuclear power involvement, multi-country events, recency, and GDELT tone. | Internal | Node.js | P0 | ✅ LIVE |
# | 007 | AI Summarizer | 1 | V1 | AI | LLM Intelligence Briefer | Sends top 20 events to LLaMA 3.1 via Groq API. Generates structured intelligence briefing with Situation Overview, Critical Developments, Strategic Assessment, and Global Threat Level. Falls back to extractive summary if LLM fails. | Groq API | LLaMA 3.1 8B | P0 | ✅ LIVE |
# | 008 | API Layer | 1 | V1 | Backend | REST API Endpoints | Three endpoints: `/api/events` (latest/hot/stats/cycle/categories), `/api/health` (system status), `/api/cron` (engine trigger with secret auth). Serves all frontend data. | Supabase | Next.js Route Handlers | P0 | ✅ LIVE |
# | 009 | Dashboard | 1 | V1 | Frontend | Live Intelligence Dashboard | Dark-themed real-time dashboard showing global stats, AI briefing, category filters, region filters, sort controls, and heat-coded event cards. Auto-refreshes every 60 seconds. | Internal API | Next.js + Tailwind | P0 | ✅ LIVE |
# | 010 | Database | 1 | V1 | Infrastructure | Supabase PostgreSQL Layer | Three tables: `wae_events`, `wae_cycles`, `wae_system_health`. 6 performance indexes. Row-level security. | Supabase | PostgreSQL | P0 | ✅ LIVE |
# | 011 | Company DB | 2 | V2.0 | Data | Company Master Database | Structured database of top 2,500 global companies. Fields: ticker, ISIN, CIN, name, aliases, country, sector, industry, employees, founded, HQ city, website, CEO, market cap. Covers NSE top 1000 + NYSE top 1000 + LSE top 500. | Wikidata + NSE/BSE APIs + manual seed | PostgreSQL | P0 | 🔲 PLANNED |
# | 012 | Alias Engine | 2 | V2.0 | Data | Company Aliases Resolver | Resolves "Reliance" = "Reliance Industries" = "RIL" = "RELIANCE.NS". Fuzzy matching at 85% threshold. Powers entity extraction from news articles. Stored as PostgreSQL text array. | Internal | pg_trgm + custom fuzzy | P0 | 🔲 PLANNED |
# | 013 | Event Linker | 2 | V2.0 | Processing | Event-to-Company Linker | When any event mentions a company (directly or via alias), creates a weighted link. Strength based on: direct mention, title vs body, source credibility, mention count. Stores in `wae_event_company_links`. | Internal | NLP + PostgreSQL | P0 | 🔲 PLANNED |
# | 014 | Company API | 2 | V2.0 | Backend | Company Profile API | `GET /api/company/:ticker`. Returns full company object: basic info, recent events, risk score, financial snapshot, related companies. Cached 5 minutes in memory. | Supabase | Next.js + node-cache | P0 | 🔲 PLANNED |
# | 015 | Company Search | 2 | V2.0 | Frontend | Global Company Search | Autocomplete search bar. Type "Reliance" → shows all Reliance Group companies with ticker and sector. Full-text + trigram search. Results in under 200ms. | PostgreSQL full-text | pg_trgm | P0 | 🔲 PLANNED |
# | 016 | EDGAR Connector | 2 | V2.1 | Data Ingestion | SEC EDGAR Filings Puller | Pulls all 10-K, 10-Q, 8-K filings for all US-listed companies in our database. Stores raw filing metadata and document links. Free, no auth required. | SEC EDGAR API | Node.js fetch | P1 | 🔲 PLANNED |
# | 017 | SEBI Connector | 2 | V2.1 | Data Ingestion | India Filings Puller | Pulls annual reports, quarterly results, board meeting outcomes, and regulatory disclosures from BSE/NSE/MCA APIs. Handles PDF downloads automatically. | BSE API + NSE API + MCA | Node.js + Axios | P1 | 🔲 PLANNED |
# | 018 | Filing Parser | 2 | V2.1 | Processing | PDF-to-Structured-Data Engine | Converts regulatory filings from PDF to structured JSON. Uses pdfplumber for text, tabula-py for tables, LLM for narrative sections. Output follows standardized financial data model. | Internal | Python + pdfplumber + tabula | P1 | 🔲 PLANNED |
# | 019 | Geo Extractor | 2 | V2.1 | Processing | Revenue Geography Extractor | Extracts "Revenue by Geography" tables from annual reports. Outputs `{country: percentage, absolute_value}` per company per year. Tracks year-over-year changes. Powers exposure maps. | Filing Parser output | LLM + regex | P0 | 🔲 PLANNED |
# | 020 | Segment Reporter | 2 | V2.1 | Processing | Business Segment Analyzer | Extracts revenue and operating profit by business segment from filings. Tracks segment evolution over time (new, discontinued, renamed). Feeds into exposure and risk calculations. | Filing Parser output | LLM + tabula | P1 | 🔲 PLANNED |
# | 021 | Country Risk Engine | 2 | V2.2 | AI | Per-Country Risk Scorer | Calculates 0–100 risk score per country, updated hourly. Inputs: event frequency, average heat score, conflict events, sanctions status, political stability, economic indicators. | WAE events + external indices | Statistical model | P0 | 🔲 PLANNED |
# | 022 | Channel Detector | 2 | V2.2 | AI | Impact Channel Classifier | For each event, identifies which economic channels it operates through: sanctions_risk, energy_supply_disruption, shipping_disruption, currency_volatility, regulatory_change, military_escalation, trade_restriction, commodity_shock. | Internal NLP | Rule-based + LLM | P0 | 🔲 PLANNED |
# | 023 | Exposure Mapper | 2 | V2.2 | AI | Company Exposure Calculator | For each company, calculates financial exposure to every country (from revenue geography), every commodity (from segments), and every supply chain dependency. Updates on new filings. | Revenue geography + segments | PostgreSQL + Python | P0 | 🔲 PLANNED |
# | 024 | Impact Engine | 2 | V2.2 | AI | Event-to-Company Impact Scorer | The core feature. Formula: `impact_score = exposure × event_severity × channel_weight × confidence`. Outputs: per-company impact score, affected revenue in currency, channels, plain-English explanation, confidence interval. | All WAE data | Statistical + LLM | P0 | 🔲 PLANNED |
# | 025 | Affected Companies API | 2 | V2.2 | Backend | Companies-at-Risk Endpoint | `GET /api/event/:id/affected-companies`. Returns ranked list of companies affected by a specific event, with impact scores, affected revenue, channels, and 1-paragraph explanation per company. Sub-2-second response. | Impact Engine | Next.js + Supabase | P0 | 🔲 PLANNED |
# | 026 | Auth System | 3 | V3.0 | Infrastructure | Multi-Tenant Authentication | Supabase Auth with custom JWT claims for roles and org membership. Supports email/password, Google OAuth, SAML 2.0 SSO for enterprise. `.edu` email auto-detection for student tier. | Supabase Auth | Supabase + Next.js | P0 | 🔲 PLANNED |
# | 027 | Org Management | 3 | V3.0 | Infrastructure | Organization & Team Manager | Multi-user orgs with RBAC (Admin, Analyst, Viewer, API-only). Isolated workspaces. Audit log for every action. Invite flow with email verification. | Supabase | PostgreSQL + RLS | P0 | 🔲 PLANNED |
# | 028 | Subscription Engine | 3 | V3.0 | Business | Payment & Tier Management | Razorpay (India) + Stripe (global). Four tiers: Free Public (24h delay), Student (free .edu), Enterprise (₹15L+/year), Institutional (₹1Cr+/year), Custom (₹5Cr+/year). Automated billing, invoicing, dunning. | Razorpay + Stripe | Next.js + webhooks | P0 | 🔲 PLANNED |
# | 029 | Rate Limiter | 3 | V3.0 | Infrastructure | API Rate Limiting & Quotas | Per-tier request limits. Free: 100 req/day. Enterprise: 10K/day. Institutional: unlimited. Per-user query tracking with live usage dashboard. Automatic throttling with informative errors. | Internal | Redis + middleware | P1 | 🔲 PLANNED |
# | 030 | Workspaces | 3 | V3.0 | Product | Private Enterprise Workspaces | Each org gets isolated dashboard: custom watchlists, saved filters, team annotations, private alerts, custom data feeds. Changes don't affect other organizations. | Supabase RLS | PostgreSQL + Next.js | P0 | 🔲 PLANNED |
# | 031 | Custom Ingestion | 3 | V3.1 | Product | Enterprise Data Upload | Enterprises add their own sources: custom RSS feeds, file uploads (PDF, Word, Excel), email forwarding, Slack/Teams channel monitoring. All data stays private to that org. | Internal | Next.js + S3 | P1 | 🔲 PLANNED |
# | 032 | Alerts Engine | 3 | V3.1 | Product | Custom Intelligence Alerts | Rule-based alert builder: "Alert when heat > 8 AND country = Iran AND channel = energy_supply". Delivery: email, Slack, Telegram, SMS (Twilio), webhook. Quiet hours, severity levels, digest mode. | Internal | Node.js + Twilio + SendGrid | P0 | 🔲 PLANNED |
# | 033 | Enterprise API | 3 | V3.1 | Backend | Full Enterprise REST API | Complete REST API with OpenAPI 3.0 documentation. All events, companies, impact scores, country risk, forecasts accessible via API key. Versioned (`/api/v2/`). Interactive docs at `/api/docs`. | All WAE data | Next.js + Swagger | P0 | 🔲 PLANNED |
# | 034 | Webhooks | 3 | V3.1 | Backend | Real-Time Event Webhooks | Push events to client systems the moment they're processed. Configurable filters (category, country, heat threshold, company). Retry logic with exponential backoff. HMAC signature verification. | Internal | Node.js + queuing | P1 | 🔲 PLANNED |
# | 035 | Export Engine | 3 | V3.1 | Product | Report & Data Export Suite | One-click exports: PDF intelligence reports, Excel data dumps, PowerPoint slide decks. Scheduled reports (daily briefing at 7 AM, weekly summary). Custom templates per org. | Internal | Puppeteer + xlsx | P1 | 🔲 PLANNED |
# | 036 | Audit Logger | 3 | V3.2 | Compliance | Tamper-Proof Audit Trail | Every user action logged: timestamp, user ID, org ID, IP, action details. Logs are append-only. Exportable for compliance audits. 7-year retention. Required for SEBI-regulated clients. | Internal | PostgreSQL + append-only | P1 | 🔲 PLANNED |
# | 037 | Data Provenance | 3 | V3.2 | Compliance | Source Citation Network | Every claim traces to its source. "Why does WAE say this?" shows: source article → extraction logic → classification rule → heat score formula. Full transparency for institutional clients. | Internal | PostgreSQL graph | P1 | 🔲 PLANNED |
# | 038 | SOC2 Prep | 3 | V3.2 | Compliance | Security & Compliance Framework | SOC 2 Type II preparation: AES-256 encryption at rest, TLS 1.3 in transit, access controls documentation, incident response playbook, penetration testing schedule, vendor risk assessments. | Internal | Infrastructure + docs | P2 | 🔲 PLANNED |
# | 039 | Data Residency | 3 | V3.2 | Infrastructure | Regional Data Isolation | India client data on India servers (Mumbai). EU on Frankfurt. US on US servers. Prevents cross-border data transfer issues for regulated institutions. | Supabase multi-region | PostgreSQL + routing | P2 | 🔲 PLANNED |
# | 040 | White Label | 3 | V3.2 | Business | White-Label Platform Option | Enterprise clients deploy WAE under their own brand. Custom domain, logo, colors, email templates, report headers. Used by consulting firms reselling WAE to their clients. | Internal | Next.js theming | P2 | 🔲 PLANNED |
# | 041 | Signal Aggregator | 4 | V4.0 | AI | Multi-Signal Intelligence Collector | Aggregates signals beyond news: event velocity trends, sentiment shifts, sanctions list updates (OFAC, EU, UN), travel advisories, military exercise announcements, diplomatic visit patterns, social media surge detection. | Multiple APIs | Node.js + Python | P0 | 🔲 PLANNED |
# | 042 | Anomaly Detector | 4 | V4.0 | AI | Statistical Anomaly Detection Engine | Detects signal patterns deviating from baseline. Methods: Z-scores on rolling 30-day windows, CUSUM change-point detection, Isolation Forest for multivariate outliers. Fires when 3+ signals simultaneously deviate. | Internal signals | Python + scikit-learn | P0 | 🔲 PLANNED |
# | 043 | Pattern Matcher | 4 | V4.0 | AI | Historical Pattern Recognition | Compares current signal cluster to historical precedents. "Current Iran pattern matches pre-2019 Gulf crisis at 78% similarity." Uses event embeddings + cosine similarity. Library of 500+ historical crisis patterns. | Historical WAE data | Python + embeddings | P0 | 🔲 PLANNED |
# | 044 | Risk Index | 4 | V4.0 | AI | Country & Sector Risk Indices | Published risk indices updated hourly per country and sector. Includes confidence intervals (not just point estimates). Methodology documented. Historical index for backtesting. Benchmarked against ICRG, WEF. | All WAE signals | Statistical model | P0 | 🔲 PLANNED |
# | 045 | Forecast Engine | 4 | V4.0 | AI | 6-Week Escalation Predictor | Probability forecast: "65% chance of military escalation in Taiwan Strait within 6 weeks." Shows top 5 drivers, confidence interval, historical accuracy of similar forecasts, and what would change the forecast. Updated every 6 hours. | All WAE data + ML | Python + XGBoost | P0 | 🔲 PLANNED |
# | 046 | Scenario Builder | 4 | V4.1 | AI | What-If Scenario Constructor | User defines a hypothetical: "Oil price hits $150/barrel" or "China blockades Taiwan". System builds structured scenario object with probability inputs and propagation rules. Saved scenarios shareable within org. | Internal | Next.js + Python | P1 | 🔲 PLANNED |
# | 047 | Impact Simulator | 4 | V4.1 | AI | Scenario Impact Propagation Engine | Runs user-defined scenario through the full impact engine. Shows cascading effects: which companies hit, which sectors rotate, which currencies move, which commodities spike. Ranked impact list with magnitude estimates. | Impact Engine + scenarios | Python + Monte Carlo | P1 | 🔲 PLANNED |
# | 048 | Backtesting Engine | 4 | V4.1 | AI | Strategy Backtester | "If I had acted on every WAE alert above heat 8 since 2023, what would my return be?" Calculates Sharpe ratio, max drawdown, win rate, average gain/loss. Benchmarked against S&P 500, Nifty 50. | Historical WAE data + market prices | Python + pandas | P2 | 🔲 PLANNED |
# | 049 | Entity Extractor | 5 | V5.0 | AI | Deep Entity Extraction Engine | Extracts from every article: named people (with titles and affiliations), organizations, locations (with coordinates), events (with dates), products, financial instruments. LLM + NER hybrid. 95%+ accuracy target. | All WAE articles | spaCy + LLM | P0 | 🔲 PLANNED |
# | 050 | Relationship Extractor | 5 | V5.0 | AI | Entity Relationship Detector | Identifies relationships: "Apple sources chips from TSMC", "Mukesh Ambani controls Reliance", "Saudi Arabia sanctioned by EU". LLM for relationship type classification with confidence scores. Handles temporal relationships. | Entity Extractor output | LLM + rule-based | P0 | 🔲 PLANNED |
# | 051 | Knowledge Graph | 5 | V5.0 | Infrastructure | Global Knowledge Graph (Neo4j) | Graph database with nodes for Companies, People, Countries, Events, Products. Edges for: owns, supplies, competes, located_in, sanctioned_by, partners_with, employs, regulates. Target: 10M+ nodes within 12 months. | Entity + Relationship extractors | Neo4j | P0 | 🔲 PLANNED |
# | 052 | Graph Query Engine | 5 | V5.0 | Backend | Knowledge Graph Query Interface | Natural language + Cypher query interface. "Show me all companies owned by Adani Group with Middle East revenue exposure." Returns structured results + visual graph. Sub-3-second response on 10M node graph. | Neo4j | Neo4j + D3.js | P0 | 🔲 PLANNED |
# | 053 | Ripple Engine | 5 | V5.0 | AI | Supply Chain Ripple Effect Calculator | Given a company or country shock, traverses knowledge graph to calculate 1st, 2nd, and 3rd order affected entities. "If Foxconn halts: Apple affected (1st), 200 Apple suppliers (2nd), 40,000 retail partners (3rd)." | Knowledge Graph | Neo4j graph algorithms | P0 | 🔲 PLANNED |
# | 054 | Network Analyzer | 5 | V5.0 | AI | Entity Network Intelligence | Calculates centrality scores (most connected/influential entities), detects communities (clusters of tightly linked entities), finds shortest paths between any two entities, maps influence propagation. | Knowledge Graph | Neo4j + Python networkx | P1 | 🔲 PLANNED |
# | 055 | WAE Chat | 6 | V6.0 | AI | Conversational Intelligence Interface | Chat with WAE in natural language. "Which Indian companies are exposed to China-Taiwan?" Full conversation memory within session. Every answer cites sources. Voice input supported. | All WAE data + LLM | GPT-4o / Claude 3.5 + RAG | P0 | 🔲 PLANNED |
# | 056 | Specialized Agents | 6 | V6.0 | AI | Domain-Expert AI Analyst Agents | Six specialized agents: Geopolitics Analyst, Energy Markets Analyst, Defense Intelligence Analyst, Macro Economist, Indian Markets Specialist, Emerging Markets Analyst. Each has its own system prompt, tool access, and memory. | All WAE data | LLM + tool use | P0 | 🔲 PLANNED |
# | 057 | Multi-Agent System | 6 | V6.0 | AI | Agent Collaboration Framework | Agents collaborate on complex queries. "What's the macro + geopolitical + energy combined view on Russia?" Routes to 3 agents, each contributes, coordinator synthesizes into unified briefing. | Specialized Agents | LLM orchestration | P1 | 🔲 PLANNED |
# | 058 | Daily Briefings | 6 | V6.0 | Product | Personalized Morning Intelligence Brief | 7 AM email briefing customized per user based on watchlist, sector focus, country interests, and role. Overnight events, market opens, day's key risks. Optional voice version (TTS). Push notification on mobile. | All WAE data + user prefs | LLM + SendGrid + TTS | P0 | 🔲 PLANNED |
# | 059 | Custom Agent Builder | 6 | V6.0 | Product | Enterprise Agent Customization Studio | Enterprise clients define their own AI agents: upload internal docs, set focus areas, define output format, set tone. "Create an agent monitoring our portfolio companies for supply chain risks." No-code interface. | Enterprise docs + LLM | RAG + fine-tuning | P1 | 🔲 PLANNED |
# | 060 | Report Generator | 6 | V6.0 | Product | Institutional Research Report Engine | "Generate a full intelligence report on Reliance Industries." Output: 15–20 page PDF with executive summary, financials, geography exposure, risk factors, recent events, network diagram, forward outlook. Generated in 5 minutes. | All WAE data + LLM | LLM + Puppeteer | P0 | 🔲 PLANNED |
# | 061 | Market Data Live | 7 | V7.0 | Data Ingestion | Real-Time Market Data Feeds | Live prices: NSE/BSE stocks (1,500+), NYSE/NASDAQ (3,000+), LSE (500+), 50+ forex pairs, top 100 crypto, 20+ commodities, 30 sovereign bond yields. | Yahoo Finance + Alpha Vantage + Binance | WebSocket streams | P0 | 🔲 PLANNED |
# | 062 | Historical Market DB | 7 | V7.0 | Data | Historical Price Database | 20+ years of daily OHLCV for all tracked instruments. Minute-bar data for last 2 years. Tick data for last 30 days. Stored in TimescaleDB. Powers backtesting and correlation analysis. | Multiple market data providers | TimescaleDB | P1 | 🔲 PLANNED |
# | 063 | Economic Indicators | 7 | V7.0 | Data | Macro Economic Indicator Tracker | Tracks 200+ economic indicators per country: GDP, CPI, PMI, unemployment, current account, FDI flows, industrial production, retail sales. Updated as releases happen. Shows actual vs estimate vs previous. | World Bank + FRED + RBI + Mospi | Node.js schedulers | P0 | 🔲 PLANNED |
# | 064 | Earnings Calendar | 7 | V7.0 | Product | Corporate Earnings Intelligence | Complete earnings calendar for all tracked companies. EPS estimate (consensus), revenue estimate, previous actual, historical beat/miss rate, analyst sentiment. Alerts 24h before earnings. Post-earnings analysis within 10 minutes. | Alpha Vantage + BSE/NSE | Scheduled scraping | P1 | 🔲 PLANNED |
# | 065 | Trading Charts | 7 | V7.0 | Frontend | Professional Trading Chart Suite | TradingView Lightweight Charts for all instruments. Full technical analysis: candlesticks, RSI, MACD, Bollinger Bands, moving averages, volume. WAE events overlaid on price chart as markers. | TradingView + market data | TradingView library | P0 | 🔲 PLANNED |
# | 066 | Correlation Engine | 7 | V7.0 | AI | Event-to-Market Correlation Calculator | "When a Middle East conflict event with heat > 7 occurs, Brent crude moves +3.2% on average within 4 hours, confidence 0.74." Correlation matrix across all event types and instruments. Updated with each new event. | WAE events + market history | Python + pandas | P0 | 🔲 PLANNED |
# | 067 | Satellite Intel | 8 | V8.0 | Data Ingestion | Satellite Imagery Intelligence | Processes publicly available satellite imagery (NASA GIBS, Copernicus Sentinel). Monitors factory parking lots, port congestion, agricultural land use, construction progress. Flags significant changes automatically. | NASA + ESA Copernicus | Python + GDAL + CV | P2 | 🔲 PLANNED |
# | 068 | Maritime Tracker | 8 | V8.0 | Data Ingestion | Global Vessel Tracking System | Tracks 100,000+ vessels in real-time via AIS data. Detects: route deviations, dark ship behavior (AIS off), port congestion, fleet positioning in sensitive areas. Correlated with geopolitical events. | MarineTraffic API | Node.js + PostGIS | P1 | 🔲 PLANNED |
# | 069 | Aviation Tracker | 8 | V8.0 | Data Ingestion | Flight Pattern Intelligence | Tracks commercial and government aircraft via ADS-B data (OpenSky free). Monitors government/military jet patterns, diplomatic routes, unusual cargo activity. "3 Saudi royal jets landed in Geneva simultaneously." | OpenSky Network API | Node.js + PostGIS | P2 | 🔲 PLANNED |
# | 070 | Job Intel | 8 | V8.0 | Data Ingestion | Job Market Signal Tracker | Monitors job postings as forward-looking signal. "Tesla posted 200 battery engineer roles in India = expansion signal." Layoff trackers (Layoffs.fyi API). Aggregates hiring velocity per company. | Indeed API + Layoffs.fyi + scraping | Python + schedulers | P1 | 🔲 PLANNED |
# | 071 | Patent Intel | 8 | V8.0 | Data Ingestion | Patent Filing Intelligence | Tracks patent filings from USPTO, EPO, IP India. Monitors innovation velocity per company, identifies emerging technology bets, detects competitive moves. "Reliance filed 40 green hydrogen patents in 6 months = major strategic bet." | USPTO API + EPO OPS | Python + schedulers | P2 | 🔲 PLANNED |
# | 072 | Web Traffic Intel | 8 | V8.0 | Data Ingestion | Digital Activity Intelligence | Tracks web traffic trends (SimilarWeb), app store rankings (App Annie), GitHub commit activity per company's open-source repos, domain registration surges. | SimilarWeb + App Annie + GitHub | Python + APIs | P2 | 🔲 PLANNED |
# | 073 | Social Listening | 8 | V8.0 | Data Ingestion | Advanced Social Signal Aggregator | Deep social monitoring: Twitter/X volume and sentiment, Reddit analysis (r/worldnews, r/geopolitics, r/investing, r/india), Telegram channel monitoring, YouTube comment sentiment on news videos. | Twitter API + Reddit API + Telegram | Python + NLP | P1 | 🔲 PLANNED |
# | 074 | Portfolio Analyzer | 9 | V9.0 | Product | Institutional Portfolio Risk Analyzer | Upload any portfolio (CSV, Excel, broker API). Instant risk decomposition: country exposure, sector concentration, geopolitical risk per holding, correlation matrix, diversification score. Benchmark against Nifty 50, S&P 500. | User portfolios + WAE data | Python + pandas | P0 | 🔲 PLANNED |
# | 075 | Trade Ideas | 9 | V9.0 | Product | AI Trade Idea Generator | Based on current events and market signals: generates long/short trade ideas with thesis, entry/exit levels, hedge suggestions, risk-reward ratio, historical similar setups. Educational context always shown. Not financial advice. | All WAE data + LLM | LLM + market data | P1 | 🔲 PLANNED |
# | 076 | Risk Suite | 9 | V9.0 | Product | Quantitative Risk Management Suite | VaR at 95% and 99% confidence, Expected Shortfall (CVaR), stress test against 20 historical scenarios (2008 crisis, COVID crash, Taper Tantrum, etc.), liquidity analysis, margin requirement calculator. | Portfolio data + market history | Python + scipy | P1 | 🔲 PLANNED |
# | 077 | Compliance Monitor | 9 | V9.0 | Product | Regulatory Compliance Screener | Sanctions screening against OFAC, EU, UN, India MEA lists. PEP database check. ESG compliance scoring. SEBI insider trading flag detection. Exportable compliance reports. Real-time watchlist updates. | OFAC API + UN sanctions + MEA | Node.js + Python | P0 | 🔲 PLANNED |
# | 078 | DD Engine | 9 | V9.0 | Product | Automated Due Diligence Generator | "Generate due diligence report on TCS." Aggregates: company profile, all recent events, financial analysis, insider activity, network relationships, risk exposure, peer comparison, red flags. 30-page PDF in 5 minutes. | All WAE data + LLM | LLM + Puppeteer | P0 | 🔲 PLANNED |
# | 079 | Autonomous Agents | 10 | V10.0 | AI | Autonomous Research Agent System | Give it a task: "Analyze the competitive landscape for green hydrogen in India 2025–2030." Agent autonomously searches all WAE data, pulls market data, finds relevant filings, interviews knowledge graph, generates 20-page report. 10 minutes vs analyst's 8 hours. | All WAE data + internet | LLM + tool-use + RAG | P0 | 🔲 PLANNED |
# | 080 | Workflow Builder | 10 | V10.0 | Product | No-Code Intelligence Automation | Visual workflow editor: "When heat > 8 AND country = China AND category = military THEN generate report AND send to Slack AND add to watchlist." Drag-and-drop. 50+ trigger types. 30+ action types. | Internal | React Flow + Node.js | P1 | 🔲 PLANNED |
# | 081 | Causal Inference | 10 | V10.0 | AI | Causal Reasoning Engine | Goes beyond correlation to causation. "Did the OPEC cut in November 2023 cause the Indian rupee move?" Uses Granger causality, DiD, Synthetic Control methods. Shows causal graph with confidence. | Historical WAE + market data | Python + econometrics | P2 | 🔲 PLANNED |
# | 082 | Multi-Modal AI | 10 | V10.0 | AI | Image, Video & Audio Intelligence | Processes non-text content: satellite images (classify military buildup vs civilian), news broadcast clips (extract spoken statements), earnings call audio (tone analysis), chart images (read chart data). Unified with text pipeline. | All media sources | GPT-4V + Whisper + CV | P1 | 🔲 PLANNED |
# | 083 | Disinfo Detector | 10 | V10.0 | AI | Disinformation & Deepfake Detection | Identifies AI-generated content in news cycle, cross-verifies claims across 3+ independent sources, detects coordinated inauthentic behavior, flags suspected state-sponsored disinformation with evidence. | All WAE sources | LLM + cross-reference | P1 | 🔲 PLANNED |
# | 084 | Multi-Language | 11 | V11.0 | Data | 50-Language Content Processing | Ingest, translate, and analyze content in 50+ languages. Arabic news, Mandarin state media, Russian Telegram, Hindi TV transcripts, Spanish LATAM, Farsi sources. Native sentiment analysis in each language before translation. | 50+ language sources | mBERT + DeepL API | P0 | 🔲 PLANNED |
# | 085 | Regional Modules | 11 | V11.0 | Product | Deep Regional Intelligence Packs | Specialized coverage packs: India Pack (500+ local sources, vernacular media, state govt data), China Pack, Middle East Pack (Arabic + English + Farsi), Africa Pack (50+ African outlets). Each with regional expert curation. | Regional sources | Modular source system | P0 | 🔲 PLANNED |
# | 086 | Regulatory Modules | 11 | V11.0 | Product | Jurisdiction-Specific Compliance Packs | SEBI pack, SEC pack, FCA pack, MAS pack, ESMA pack. Each monitors regulatory announcements, new rules, enforcement actions, and their impact on tracked companies. | Regulatory APIs per jurisdiction | Scheduled scrapers | P1 | 🔲 PLANNED |
# | 087 | Data Partnerships | 11 | V11.0 | Business | Proprietary Data Source Agreements | Formal data partnerships: Indian state government data (MoU), emerging market data providers, specialist OSINT networks, academic research institutions. Creates data moat competitors cannot replicate. | Partnership agreements | Custom integrations | P1 | 🔲 PLANNED |
# | 088 | Desktop Terminal | 12 | V12.0 | Frontend | Professional Desktop Application | Electron-based desktop app for Windows, Mac, Linux. Multi-monitor support with draggable panels. Bloomberg-style keyboard shortcuts. Always-on mode (system tray). Offline data caching. Custom layout saving. | Internal | Electron + React | P0 | 🔲 PLANNED |
# | 089 | Mobile Apps | 12 | V12.0 | Frontend | Native iOS & Android Applications | Full-featured mobile apps with real-time push notifications, offline mode for saved briefings, voice briefings during commute, biometric authentication, Apple Watch + Wear OS companion apps. | Internal | React Native | P0 | 🔲 PLANNED |
# | 090 | Trader Messaging | 12 | V12.0 | Product | Institutional Analyst Chat Network | Encrypted messaging between verified institutional WAE users. Share private alerts, annotated events, trade theses. Group channels by sector or geography. Bloomberg IB-style built into the intelligence platform. KYC required. | Internal | WebSocket + encryption | P1 | 🔲 PLANNED |
# | 091 | Trading Integration | 12 | V12.0 | Product | Direct Broker Trade Execution | Connect personal brokerage accounts (Interactive Brokers, Zerodha, Upstox). One-click execution from WAE dashboard. Risk limit pre-approval workflow. Trade history and P&L tracking. WAE event linked to every trade. | Broker APIs | Broker SDKs | P2 | 🔲 PLANNED |
# | 092 | Voice Assistant | 12 | V12.0 | Product | WAE Voice Interface | Fully voice-driven interaction. "WAE, give me the morning brief." Phone call interface (call a number, get your briefing). In-meeting quiet mode. Works with Alexa, Google Home, Siri Shortcuts. | Internal + TTS/STT | Whisper + ElevenLabs | P1 | 🔲 PLANNED |
# | 093 | AR/VR Interface | 12 | V12.0 | Frontend | Spatial Computing Intelligence Center | Apple Vision Pro + Meta Quest app. 3D globe with heat event markers you can reach out and touch. Spatial data visualization panels floating in space. Virtual intelligence operations center. | Internal | Unity + WebXR | P2 | 🔲 PLANNED |
#
# ---
#
# ## Summary Statistics
#
# | Metric | Count |
# |--------|-------|
# | **Total Modules** | 93 |
# | **Live in V1** | 10 |
# | **Planned V2** | 15 |
# | **Planned V3** | 15 |
# | **Planned V4** | 8 |
# | **Planned V5** | 6 |
# | **Planned V6** | 6 |
# | **Planned V7** | 6 |
# | **Planned V8** | 7 |
# | **Planned V9** | 5 |
# | **Planned V10** | 5 |
# | **Planned V11** | 4 |
# | **Planned V12** | 6 |
#
# ---
#
# ## Version Roadmap
#
# | Version | Phase | Focus Area | Key Deliverable |
# |---------|-------|-----------|----------------|
# | **V1** *(LIVE)* | 1 | Core Engine | Live intelligence dashboard, 10 modules running |
# | **V2.0–V2.2** | 2 | Company Intelligence | Company DB, aliases, event linking, exposure mapping, impact scoring |
# | **V3.0–V3.2** | 3 | Enterprise Platform | Auth, orgs, payments, workspaces, alerts, compliance |
# | **V4.0–V4.1** | 4 | Predictive AI | Anomaly detection, pattern matching, forecasting, scenario simulation |
# | **V5.0** | 5 | Knowledge Graph | Entity extraction, relationships, Neo4j, supply chain ripple |
# | **V6.0** | 6 | Agentic AI | Conversational interface, specialized agents, report generation |
# | **V7.0** | 7 | Market Intelligence | Live prices, historical DB, macro indicators, trading charts |
# | **V8.0** | 8 | Alternative Data | Satellite, maritime, aviation, jobs, patents, social |
# | **V9.0** | 9 | Investment Suite | Portfolio risk, compliance, due diligence, trade ideas |
# | **V10.0** | 10 | Autonomous Intelligence | Autonomous agents, workflow builder, causal inference |
# | **V11.0** | 11 | Global Expansion | 50 languages, regional packs, regulatory modules |
# | **V12.0** | 12 | Platform Completion | Desktop terminal, mobile apps, voice, AR/VR |
#
# ---
#
# ## Priority Legend
#
# | Priority | Meaning |
# |----------|---------|
# | **P0** | Cannot ship that version without it — core functionality |
# | **P1** | Ships with version but can be simplified if time-constrained |
# | **P2** | Nice-to-have — moved to next version if needed |
#
# ---
#
# ## Status Legend
#
# | Status | Meaning |
# |--------|---------|
# | ✅ **LIVE** | Built, tested, running in production |
# | 🔲 **PLANNED** | Designed, not yet built |
# | 🔄 **IN PROGRESS** | Currently being built |
# | ⚠️ **BLOCKED** | Waiting on a dependency |
#
# ---
#
# > **Now deploy V1. Then we build every single one of these.** 🚀
